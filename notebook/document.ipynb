# %% [markdown]
# ## Data Ingestion

# %%
###Document Structure

from langchain_core.documents import Document

# %%
doc=Document(
    page_content="This is the main text content i'm using to create RAG",
    metadata={"source": "example.txt",
              "pages": 1,
              "author": "Krishna Sharma",
              "date_created": "2026-06-7"}
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Krishna Sharma', 'date_created': '2026-06-7'}, page_content="This is the main text content i'm using to create RAG")

# %%
## create a simple txt file to test the document structure
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_text ={
    "../data/text_files/python_intro.txt":"""Python Programming Language

Python is a high-level, interpreted, and general-purpose programming language.
It is known for its simple syntax and easy readability.

Features of Python:
1. Easy to learn
2. Simple syntax
3. Open-source
4. Cross-platform

Applications of Python:
- Web Development
- Data Science
- Machine Learning
- Artificial Intelligence
- Automation
""",
"../data/text_files/machine_learning.txt":"""Machine Learning

Machine Learning is a branch of Artificial Intelligence.
It enables computers to learn patterns from data
and make predictions without being explicitly programmed.

Types of Machine Learning:
1. Supervised Learning
2. Unsupervised Learning
3. Reinforcement Learning

Applications:
- Recommendation Systems
- Fraud Detection
- Image Recognition
- Healthcare
- Automation"""
}

for file_path, content in sample_text.items():
    with open(file_path,'w', encoding="utf-8") as f:
        f.write(content)

print("sample text files created successfully in ../data/text_files directory.")
# Out:
# sample text files created successfully in ../data/text_files directory.

# %%
### TextLoader

from langchain.document_loaders import TextLoader
from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Language\n\nPython is a high-level, interpreted, and general-purpose programming language.\nIt is known for its simple syntax and easy readability.\n\nFeatures of Python:\n1. Easy to learn\n2. Simple syntax\n3. Open-source\n4. Cross-platform\n\nApplications of Python:\n- Web Development\n- Data Science\n- Machine Learning\n- Artificial Intelligence\n- Automation\n')]

# %%
### DirectoryLoader

from langchain_community.document_loaders import DirectoryLoader
#load all text files from the directory
dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",    #pattern to match the files
    loader_cls=TextLoader,      #loader class to use
    loader_kwargs={"encoding": "utf-8"},
    show_progress=False
)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Language\n\nPython is a high-level, interpreted, and general-purpose programming language.\nIt is known for its simple syntax and easy readability.\n\nFeatures of Python:\n1. Easy to learn\n2. Simple syntax\n3. Open-source\n4. Cross-platform\n\nApplications of Python:\n- Web Development\n- Data Science\n- Machine Learning\n- Artificial Intelligence\n- Automation\n'),
#  Document(metadata={'source': '../data/text_files/machine_learning.txt'}, page_content='Machine Learning\n\nMachine Learning is a branch of Artificial Intelligence.\nIt enables computers to learn patterns from data\nand make predictions without being explicitly programmed.\n\nTypes of Machine Learning:\n1. Supervised Learning\n2. Unsupervised Learning\n3. Reinforcement Learning\n\nApplications:\n- Recommendation Systems\n- Fraud Detection\n- Image Recognition\n- Healthcare\n- Automation')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader
#load all text files from the directory
dir_loader=DirectoryLoader(
    "../data/pdf_files",
    glob="**/*.pdf",    #pattern to match the files
    loader_cls=PyMuPDFLoader,      #loader class to use
    show_progress=False
)

pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'macOS Version 15.3.2 (Build 24D81) Quartz PDFContext', 'creator': 'Pages', 'creationdate': "D:20250406124457Z00'00'", 'source': '../data/pdf_files/conditional sent. pre assesment.pdf', 'file_path': '../data/pdf_files/conditional sent. pre assesment.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': 'conditional sent. pre assesment', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20250406124457Z00'00'", 'trapped': '', 'modDate': "D:20250406124457Z00'00'", 'creationDate': "D:20250406124457Z00'00'", 'page': 0}, page_content='ANSHIKA THAKUR - 24SCSE1180664 \nPre-Assessment: Conditional Sentences \nInstructions: Read each question carefully and choose the correct answer or fill in the blanks \nwith the correct verb form. \n1. Multiple Choice (Identify the Type of Conditional Sentence) \n1. If you heat water to 100°C, it ____ (boil).zero conditional \na) boils \nb) will boil \nc) would boil \nd) boiled \n2. If I ____ enough money, I would buy
# ...

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document

# %% [markdown]
# ## Embedding and VectorStoreDB
